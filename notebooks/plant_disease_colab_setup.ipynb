# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruthiSannu11/plant-disease-detection/blob/main/notebooks/plant_disease_colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌿 Plant Disease Detection System — Google Colab & Google Drive Setup
#
# This notebook automates downloading the **PlantVillage 38-Class Dataset**, preprocessing & cleaning leaf images, and permanently storing dataset splits in **Google Drive Cloud Storage** (0 MB local storage required on your computer).

# %% [markdown]
# ## Step 1: Environment & Google Drive Integration

# %%
# Check Cloud GPU acceleration
# !nvidia-smi

# Mount Google Drive to save processed dataset permanently
from google.colab import drive
drive.mount('/content/drive')

# Clone project repo
# !git clone https://github.com/DhruthiSannu11/plant-disease-detection.git
# %cd plant-disease-detection

# Install Python requirements
# !pip install -r backend/requirements.txt kagglehub dvc pillow tqdm

# %% [markdown]
# ## Step 2: Download PlantVillage Dataset in Colab Cloud Storage

# %%
# Execute dataset downloader script inside Colab
# !python scripts/dataset_downloader.py --output-dir data/raw

# %% [markdown]
# ## Step 3: Dataset Cleaning, Resizing (224x224 RGB) & Save to Google Drive

# %%
# Define Google Drive destination path
DRIVE_DATASET_DIR = '/content/drive/MyDrive/plant_disease_dataset/processed'

# Execute preprocessing script outputting directly to Google Drive
# !python scripts/preprocess_dataset.py --raw-dir data/raw/plantvillage --output-dir "$DRIVE_DATASET_DIR"

# %% [markdown]
# ## Step 4: Verify Dataset Split Summary in Google Drive

# %%
import json
summary_path = '/content/drive/MyDrive/plant_disease_dataset/processed/dataset_summary.json'
with open(summary_path) as f:
    summary = json.load(f)
print(f"✅ Total Processed Images : {summary['total_images']}")
print(f"🌿 Total Disease Classes  : {summary['total_classes']}")
print(f"🏋️ Train Set Count       : {summary['train_count']}")
print(f"📊 Val Set Count         : {summary['val_count']}")
print(f"🧪 Test Set Count        : {summary['test_count']}")
