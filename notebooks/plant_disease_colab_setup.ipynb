# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruthiSannu11/plant-disease-detection/blob/main/notebooks/plant_disease_colab_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌿 Plant Disease Detection System — Google Colab Setup & Cloud Execution
#
# This notebook automates downloading the **PlantVillage 38-Class Dataset**, preprocessing & cleaning leaf images, and preparing PyTorch model training directly inside Google Colab's cloud environment (0 MB local storage required).

# %% [markdown]
# ## Step 1: Environment & Repository Initialization

# %%
# Check Cloud GPU acceleration
# !nvidia-smi

# Clone project repo (Replace URL with your repository URL if private)
# !git clone https://github.com/DhruthiSannu11/plant-disease-detection.git
# %cd plant-disease-detection

# Install Python requirements
# !pip install -r backend/requirements.txt kagglehub dvc pillow tqdm
# Out:
# /bin/bash: line 1: nvidia-smi: command not found
# Cloning into 'plant-disease-detection'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 46 (delta 4), reused 45 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 42.00 KiB | 2.21 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# /content/plant-disease-detection
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.1/470.1 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 78.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 90.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 560.6/560.6 kB 39.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.8/73.8 kB 6.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Step 2: Download PlantVillage Dataset in Cloud Storage

# %%
# Execute dataset downloader script inside Colab
# !python scripts/dataset_downloader.py --output-dir data/raw
# Out:
# 📥 Downloading via kagglehub (abdallahalmamun/plantvillage-dataset)...
# ⚠️ Kagglehub download skipped (403 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDataset. Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.). Falling back to HTTP archive...
# 📥 Downloading dataset from: https://github.com/spMohanty/PlantVillage-Dataset/archive/refs/heads/master.zip
# 💾 Saving to: /content/plant-disease-detection/data/raw/plantvillage_dataset.zip
#  progress: 0% [2388.3 MB / 0.0 MB]
# ✅ Download complete!
# 📦 Extracting plantvillage_dataset.zip to /content/plant-disease-detection/data/raw...
# ✅ Extraction complete!
# 📁 Organizing class folders from /content/plant-disease-detection/data/raw/PlantVillage-Dataset-master/raw/color...
# ✅ Organised class directories into: /content/plant-disease-detection/data/raw/plantvillage
# ...

# %% [markdown]
# ## Step 3: Dataset Cleaning, Resizing (224x224 RGB) & 80/10/10 Split

# %%
# Execute preprocessing script
# !python scripts/preprocess_dataset.py --raw-dir data/raw/plantvillage --output-dir data/processed
# Out:
# 🔍 Found 38 disease classes in plantvillage
# ⚙️ Preprocessing (Resizing to 224x224 RGB, Splitting 80/10/10)...
#  [1/38] Processed Blueberry___healthy: 1502 images (Train: 1201, Val: 150, Test: 151)
#  [2/38] Processed Apple___Apple_scab: 630 images (Train: 504, Val: 63, Test: 63)
#  [3/38] Processed Apple___Cedar_apple_rust: 275 images (Train: 220, Val: 27, Test: 28)
#  [4/38] Processed Potato___healthy: 152 images (Train: 121, Val: 15, Test: 16)
#  [5/38] Processed Grape___Black_rot: 1180 images (Train: 944, Val: 118, Test: 118)
#  [6/38] Processed Grape___healthy: 423 images (Train: 338, Val: 42, Test: 43)
#  [7/38] Processed Tomato___Late_blight: 1909 images (Train: 1527, Val: 190, Test: 192)
#  [8/38] Processed Grape___Esca_(Black_Measles): 1383 images (Train: 1106, Val: 138, Test: 139)
#  [9/38] Processed Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot: 513 images (Train: 410, Val: 51, Test: 52)
# ...

# %% [markdown]
# ## Step 4: Verify Dataset Split Summary

# %%
import json
with open('data/processed/dataset_summary.json') as f:
    summary = json.load(f)
print(f"✅ Total Processed Images : {summary['total_images']}")
print(f"🌿 Total Disease Classes  : {summary['total_classes']}")
print(f"🏋️ Train Set Count       : {summary['train_count']}")
print(f"📊 Val Set Count         : {summary['val_count']}")
print(f"🧪 Test Set Count        : {summary['test_count']}")
# Out:
# ✅ Total Processed Images : 54305
# 🌿 Total Disease Classes  : 38
# 🏋️ Train Set Count       : 43429
# 📊 Val Set Count         : 5417
# 🧪 Test Set Count        : 5459
